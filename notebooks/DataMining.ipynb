# %%
import subprocess, sys

_packages = [
    "pandas",
    "numpy",
    "scikit-learn",
    "matplotlib",
    "fugashi[unidic-lite]",
    "mlxtend",
]

subprocess.check_call([sys.executable, "-m", "pip", "install", "--quiet"] + _packages)
print("All packages installed.")
# Out:
# All packages installed.
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

DATA_PATH = "../data/japanese_news.csv"

df = pd.read_csv(DATA_PATH, sep="\t")

print("Rows:", len(df))
print(df.head())
# Out:
# Rows: 312955
#           source        date title author  \
# 0  kobe-np.co.jp  2005-07-01   NaN    NaN
# 1  kobe-np.co.jp  2005-07-01   NaN    NaN
# 2  kobe-np.co.jp  2007-04-07   NaN    NaN
# 3  kobe-np.co.jp  2007-04-07   NaN    NaN
# 4  kobe-np.co.jp  2007-04-07   NaN    NaN
#
#                                                 text
# 0  会見した北口寛人市長は「刑事訴訟で被告となっている職員にはそれぞれ主張があるが、組織全体とし...
# 1  明石・歩道橋事故をめぐる民事訴訟で、神戸地裁から計五億六千八百万円の賠償を命じられた兵庫県（...
# 2  会見後、遺族代理人の渡部吉泰弁護士は「裁判長が『問うべき者を問わないのは正義に反する』とはっ...
# 3           遺族会は、雑踏警備本部長を務めた元明石署長ら二人の起訴を求め、活動を続けている。
# 4  五人の遺族が閉廷後に会見。二女の優衣菜ちゃん＝当時（８つ）＝を亡くした三木清さん（３８）＝姫...
# /var/folders/sc/ytp3g0vj4mdbsfqr4zyn9pnc0000gn/T/ipykernel_21624/2041196340.py:5: DtypeWarning: Columns (0: title, 1: author) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DATA_PATH, sep="\t")

# %%
# preprocessed
df = df[df["text"].notnull() & (df["text"].str.strip() != "")].copy()
print("Rows with non-empty text:", len(df))

df["char_len"] = df["text"].str.len()
print(df["char_len"].describe())
# Out:
# Rows with non-empty text: 312954
# count    312954.000000
# mean        102.669881
# std          58.882429
# min           1.000000
# 25%          66.000000
# 50%          99.000000
# 75%         133.000000
# max        5066.000000
# Name: char_len, dtype: float64

# %%
from collections import Counter
sample_text = "\n".join(df["text"])
# preprocessed freq
char_counts = Counter("".join(df["text"]))
i=1
for ch, c in char_counts.most_common(100):
    print(f'Rank {i}: {repr(ch)}, {c}')
    i+=1
# Out:
# Rank 1: 'の', 1023191
# Rank 2: '、', 841868
# Rank 3: '。', 705084
# Rank 4: 'た', 691813
# Rank 5: 'に', 636673
# Rank 6: 'を', 603051
# Rank 7: 'い', 563467
# Rank 8: 'し', 542402
# Rank 9: 'は', 535823
# Rank 10: 'と', 530330
# Rank 11: 'が', 512111
# Rank 12: 'る', 510597
# Rank 13: 'で', 495140
# Rank 14: 'て', 407929
# Rank 15: 'な', 385223
# Rank 16: 'ー', 366059
# Rank 17: 'か', 281300
# Rank 18: 'っ', 267256
# Rank 19: '１', 259989
# Rank 20: 'れ', 247426
# Rank 21: '）', 236005
# Rank 22: '（', 235943
# Rank 23: 'ン', 231814
# Rank 24: 'ら', 230590
# Rank 25: '「', 218401
# Rank 26: '」', 218398
# Rank 27: 'も', 215013
# Rank 28: 'す', 211645
# Rank 29: '日', 210417
# Rank 30: '２', 202409
# Rank 31: 'り', 199593
# Rank 32: '０', 188170
# Rank 33: 'う', 178772
# Rank 34: 'ま', 162048
# Rank 35: 'さ', 155015
# Rank 36: 'こ', 147398
# Rank 37: 'ス', 143890
# Rank 38: 'ル', 141430
# Rank 39: 'ト', 138473
# Rank 40: 'き', 137614
# Rank 41: 'だ', 135771
# Rank 42: '３', 132108
# Rank 43: 'く', 129526
# Rank 44: '年', 126018
# Rank 45: 'ん', 125482
# Rank 46: '大', 124491
# Rank 47: 'け', 120537
# Rank 48: 'め', 117331
# Rank 49: 'ど', 116633
# Rank 50: '人', 113743
# Rank 51: 'イ', 107636
# Rank 52: '会', 103569
# Rank 53: 'や', 100934
# Rank 54: '５', 98853
# Rank 55: 'あ', 97324
# Rank 56: '４', 95715
# Rank 57: 'え', 91267
# Rank 58: '本', 88703
# Rank 59: '市', 87910
# Rank 60: 'ッ', 86441
# Rank 61: 'ア', 85722
# Rank 62: '・', 83984
# Rank 63: '国', 83826
# Rank 64: 'ラ', 83597
# Rank 65: 'リ', 83109
# Rank 66: 'よ', 83069
# Rank 67: 'つ', 81043
# Rank 68: 'ク', 79343
# Rank 69: '中', 78042
# Rank 70: '６', 76855
# Rank 71: '月', 75441
# Rank 72: '同', 74541
# Rank 73: '出', 73492
# Rank 74: '７', 70441
# Rank 75: '９', 67211
# Rank 76: '８', 67184
# Rank 77: '一', 67062
# Rank 78: '上', 65818
# Rank 79: '発', 65556
# Rank 80: '者', 65488
# Rank 81: 'ド', 65073
# Rank 82: 'タ', 65045
# Rank 83: 'わ', 64421
# Rank 84: 'ち', 62627
# Rank 85: '手', 61036
# Rank 86: 'シ', 60874
# Rank 87: '地', 60734
# Rank 88: '長', 60597
# Rank 89: 'そ', 59745
# Rank 90: 'ロ', 58599
# Rank 91: '場', 57900
# Rank 92: '時', 57291
# Rank 93: '事', 57149
# Rank 94: 'フ', 56651
# Rank 95: 'み', 55478
# Rank 96: '後', 54387
# Rank 97: '行', 54367
# Rank 98: '生', 54232
# Rank 99: '合', 54063
# Rank 100: 'せ', 53949

# %%
from fugashi import Tagger

tagger = Tagger()  

STOPWORDS = {
    # generic 動詞
    "する", "いる", "ある", "なる", "できる", "くる", "いく",

    # generic 名詞
    "こと", "ところ", "もの", "よう", "ため", "とき",

    # 時間漢字
    "年", "月", "日",

    # ひらがな
    "あ", "い", "う", "え", "お", "か", "き", "く", "け", "こ", "さ", "し", "す", "せ", "そ", "た", "ち", "つ", "て", "と", "な", "に", "ぬ", "ね", "の", "は", "ひ", "ふ", "へ", "ほ", "ま", "み", "む", "め", "も", "や", "ゆ", "よ", "ら", "り", "る", "れ", "ろ", "わ", "を", "ん",

    # カタカナ
    "ア", "イ", "ウ", "エ", "オ", "カ", "キ", "ク", "ケ", "コ", "サ", "シ", "ス", "セ", "ソ", "タ", "チ", "ツ", "テ", "ト", "ナ", "ニ", "ヌ", "ネ", "ノ", "ハ", "ヒ", "フ", "ヘ", "ホ", "マ", "ミ", "ム", "メ", "モ", "ヤ", "ユ", "ヨ", "ラ", "リ", "ル", "レ", "ロ", "ワ", "ヲ", "ン",

    # 特別 
    "%", "。", "ー", "・", "％"
}

def tokenize(text):
    tokens = []
    for word in tagger(text):
        surface = word.surface           
        pos1 = word.feature.pos1         
        #  content words only

        if surface.isdigit() or surface in STOPWORDS:
            continue

        if pos1 in ["名詞", "動詞", "形容詞"]:
            tokens.append(surface)
    return tokens

df["tokens"] = df["text"].apply(tokenize)

# %%
for i in range(len(df["tokens"].head(20))):
    print(df["tokens"].iloc[i])
# Out:
# ['会見', '北口', '寛人', '市長', '刑事', '訴訟', '被告', 'なっ', '職員', 'それぞれ', '主張', '組織', '全体', '判決', '厳しく', '受け止め', '述べ', '原告', '下村', '誠治', '神戸', '市', '垂水', '区', '同席', '県', '判決', '受け止め', '訴え']
# ['明石', '歩道', '事故', 'めぐる', '民事', '訴訟', '神戸', '地裁', '五', '億', '六千', '八百', '万', '円', '賠償', '命じ', '兵庫', '県', '県', '警備', '会社', 'シカン', 'エヌ', 'ケイ', 'セキュリティ', '三', 'うち', '明石', '市', '三十', '控訴', '表明']
# ['会見', '遺族', '代理', '渡部', '吉', '泰', '弁護', '裁判', '問う', '者', '問わ', '正義', '反する', '述べ', '検察', '起訴', '独占', '主義', '警鐘', '鳴らす', '画期', '評価']
# ['遺族', '会', '雑踏', '警備', '本部', '務め', '元', '明石', '二人', '起訴', '求め', '活動', '続け']
# ['五', '遺族', '閉廷', '会見', '二女', '優衣', '菜', '当時', '亡くし', '三木', '清', '姫路', '市', '被告', '四', '当事', '雑踏', '事故', '再発', '防止', '活動', '携わっ', 'ほしい', '謝罪', 'つながる']
# ['弁護', '側', 'よる', '四', '被告', 'うち', '金沢', '被告', '上告', '意思', '示し', 'いう', '川口', '洋光', '大月', '美佳']
# ['苦しみ', '悲しみ', '一生', '消え', 'ずさん', '警備', '多数', '死傷', '出', '明石', '歩道', '事故', '控訴', '判決', '六', '大阪', '高裁', '警察', '明石', '市', '警備', '会社', '被告', '四', '一', '有罪', '判決', '言い渡さ', '裁判', '一', '神戸', '地裁', '民事', '裁判', '続き', '四', '被告', '以外', '過失', '責任', 'つい', '言及', '受け', '事故', '遺族', '起訴', '処分', 'なっ', '元', '明石', '二人', '責任', 'つい', '再度', '神戸', '地検', '説明', '求める', '考え']
# ['裁判', '被告', '以外', '過失', '責任', '問わ', '余地', '者', '被告', '以外', '関係', '責任', 'つい', '言及', '二男', '智仁', '同', '亡くし', '下村', '誠治', '神戸', '市', '垂水', '区', '一', '神戸', '地裁', '民事', '裁判', '被告', '以外', '過失', '責任', 'つい', '触れ', '部分', 'あっ', '今回', '含め', '地検', '対応', '注目', '話し', '神戸', '地検', '説明', '求め', '考え', '示し']
# ['心配', '下位', '低迷', '日本', 'ハム', '言い', '心', '離れ', '自分', '弱い', '時', '応援', '本当', 'ファン', '言わ', '本当', 'ファン', 'なっ', '反省', '小笠原', '選手', '新庄', '抜け', '思っ', '小笠原', '選手', '活躍', '見', '当て付け', '怒っ', 'しまい', '頑張っ', 'ほしい']
# ['反省', '離れ', '心', '心配']
# ['望む', '打順', '固定', '得点', '向上', '思い出せ', '自分', '野球']
# ['藤平', '昭夫', '会社', '札幌', '市', '東', '区']
# ['近藤', '喜美子', '会社', '北広島', '市']
# ['柏谷', '美智子', '主婦', '札幌', '市', '南', '区']
# ['坂上', '夕子', '主婦', '石狩', '市']
# ['増田', '智恵子', '主婦', '札幌', '市', '手稲', '区']
# ['今', '低迷', '選手', '面', 'ヒルマン', '監督', '采配', 'さいはい', '含め', 'よそゆき', '野球', 'よる', '自分', '野球', 'やっ', '新庄', '残し', 'くれ', '財産', '明るく', '楽しく', '試合', '楽しむ', '売り', '選手', '自分', '殻', '閉じこもり', '自慢', '守備', 'ミス', 'チャンス', 'つぶし', '下位', 'いう', '行く', '行っ', '開き直っ', '森本', '選手', '筆頭', '切り替え', '早い', '若者', 'ベンチ', '盛り上げ', 'ベテラン', 'まとめ', 'ほしい', 'アウト', '取ら', '悲しん', '互い', '声', '掛け合え', 'チーム', '活気', '勝利', 'つながる']
# ['大西', '章子', '無職', '札幌', '市', '西', '区']
# ['川田', '照夫', 'アルバイト', '札幌', '市', '西', '区']
# ['怒り', '勝利', '執念', '持て', '積極', '打撃']

# %%
# cleaned size
df["char_len"] = df["text"].str.len()
df["token_len"] = df["tokens"].str.len()

print(df[["char_len", "token_len"]].describe())
# Out:
#             char_len      token_len
# count  312954.000000  312954.000000
# mean      102.669881      25.893777
# std        58.882429      16.094761
# min         1.000000       0.000000
# 25%        66.000000      16.000000
# 50%        99.000000      25.000000
# 75%       133.000000      34.000000
# max      5066.000000    1610.000000

# %%
from collections import Counter

# cleaned freq

all_tokens = [t for doc in df["tokens"] for t in doc]
token_counts = Counter(all_tokens)

for token, cnt in token_counts.most_common(30):
    print(token, cnt)
# Out:
# 市 58553
# 日本 47759
# いう 42275
# 県 35929
# 円 33395
# なっ 30772
# 万 27944
# 会 26101
# ない 24661
# よる 24043
# 時 23125
# 回 22794
# 町 19690
# 同 18726
# つい 17950
# 前 17743
# 東京 17654
# 一 16827
# 選手 16202
# 分 15463
# 世界 14330
# 震災 13887
# あり 13864
# 人 13205
# でき 13039
# あっ 12871
# 大会 12871
# 東 12675
# 発表 12537
# 受け 12142

# %%
# top sources
top_sources = df["source"].value_counts().head(3).index

for s in top_sources:
    tokens_source = [t for doc in df.loc[df["source"] == s, "tokens"].head(2000) for t in doc]
    print("Source:", s)
    for token, cnt in Counter(tokens_source).most_common(20):
        print(" ", token, cnt)
    print()
# Out:
# Source: mainichi.jp
#   支持 676
#   自民 600
#   民主 552
#   選挙 518
#   層 518
#   区 467
#   市 343
#   割 335
#   候補 279
#   投票 261
#   政権 233
#   県 231
#   前 210
#   いう 184
#   党 179
#   衆院 178
#   前回 176
#   当選 176
#   新人 166
#   万 164
#
# Source: sankei.jp.msn.com
#   日本 422
#   いう 404
#   ない 275
#   なっ 228
#   県 228
#   よる 209
#   市 202
#   震災 176
#   中国 175
#   つい 175
#   東京 153
#   原発 152
#   学校 140
#   問題 133
#   機 127
#   受け 127
#   福島 126
#   被災 117
#   会 116
#   朝鮮 113
#
# Source: nikkei.com
#   いう 534
#   投資 387
#   企業 359
#   日本 352
#   会社 313
#   金融 296
#   取引 288
#   円 264
#   なっ 253
#   市場 253
#   株式 225
#   銀行 216
#   ない 206
#   価格 198
#   携帯 182
#   開発 172
#   経済 169
#   株 167
#   資金 166
#   米 161

# %%
# just looking at the tokens to understand
for i in range(3):
    print("==== Article", i, "====")
    print(df["text"].iloc[i][:200])   
    print(df["tokens"].iloc[i][:40])
# Out:
# ==== Article 0 ====
# 会見した北口寛人市長は「刑事訴訟で被告となっている職員にはそれぞれ主張があるが、組織全体として判決を厳しく受け止めた」と述べた。原告団長の下村誠治さん（４６）＝神戸市垂水区＝も同席。「県警も判決を真摯（しんし）に受け止めて」と訴えた。
# ['会見', '北口', '寛人', '市長', '刑事', '訴訟', '被告', 'なっ', '職員', 'それぞれ', '主張', '組織', '全体', '判決', '厳しく', '受け止め', '述べ', '原告', '下村', '誠治', '神戸', '市', '垂水', '区', '同席', '県', '判決', '受け止め', '訴え']
# ==== Article 1 ====
# 明石・歩道橋事故をめぐる民事訴訟で、神戸地裁から計五億六千八百万円の賠償を命じられた兵庫県（県警）、警備会社ニシカン（現エヌ・ケイ・セキュリティ）など三者のうち、明石市が三十日、控訴しないことを正式に表明した。
# ['明石', '歩道', '事故', 'めぐる', '民事', '訴訟', '神戸', '地裁', '五', '億', '六千', '八百', '万', '円', '賠償', '命じ', '兵庫', '県', '県', '警備', '会社', 'シカン', 'エヌ', 'ケイ', 'セキュリティ', '三', 'うち', '明石', '市', '三十', '控訴', '表明']
# ==== Article 2 ====
# 会見後、遺族代理人の渡部吉泰弁護士は「裁判長が『問うべき者を問わないのは正義に反する』とはっきり述べたのは、検察の起訴独占主義に警鐘を鳴らす画期的なことだ」と評価した。
# ['会見', '遺族', '代理', '渡部', '吉', '泰', '弁護', '裁判', '問う', '者', '問わ', '正義', '反する', '述べ', '検察', '起訴', '独占', '主義', '警鐘', '鳴らす', '画期', '評価']

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager

#bruh why are there not fonts :(), hope this is able to run on your machine
for _name in (
    "Hiragino Sans",
    "Hiragino Kaku Gothic ProN",
    "Hiragino Maru Gothic Pro",
    "Apple SD Gothic Neo",
):
    _path = font_manager.findfont(font_manager.FontProperties(family=_name))
    if _path and "DejaVu" not in _path:
        plt.rcParams["font.family"] = _name
        break
else:
    plt.rcParams["font.sans-serif"] = [
        "Hiragino Sans",
        "Hiragino Kaku Gothic ProN",
        "DejaVu Sans",
    ]
plt.rcParams["axes.unicode_minus"] = False

# graphs

df["char_len"] = df["text"].str.len()
char_p95 = np.percentile(df["char_len"], 95)

plt.figure(figsize=(8, 4))
plt.hist(df["char_len"], bins=50, range=(0, char_p95))
plt.xlabel("Number of characters per article")
plt.ylabel("Number of articles")
plt.title("Article length distribution (characters, up to 95th percentile)")
plt.tight_layout()
plt.show()


df["token_len"] = df["tokens"].str.len()
tok_p95 = np.percentile(df["token_len"], 95)

plt.figure(figsize=(8, 4))
plt.hist(df["token_len"], bins=50, range=(0, tok_p95))
plt.xlabel("Number of tokens per article")
plt.ylabel("Number of articles")
plt.title("Article length distribution (tokens, up to 95th percentile)")
plt.tight_layout()
plt.show()


source_counts = df["source"].value_counts().head(30)

plt.figure(figsize=(8, 4))
source_counts.plot(kind="bar")
plt.xlabel("Source")
plt.ylabel("Number of articles")
plt.title("Top sources by article count")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

all_tokens = [t for doc in df["tokens"] for t in doc]

token_counts = Counter(all_tokens)
top_tokens = token_counts.most_common(20)  

if top_tokens:
    tokens, counts = zip(*top_tokens)

    plt.figure(figsize=(8, 4))
    plt.bar(range(len(tokens)), counts)
    plt.xticks(range(len(tokens)), tokens, rotation=45, ha="right")
    plt.ylabel("Frequency")
    plt.title("Top 20 tokens in cleaned corpus")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Q1: Document clustering (thematic structure)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
docs_for_clustering = [" ".join(tokens) for tokens in df["tokens"]]

vectorizer = TfidfVectorizer(
    token_pattern=r"[^ ]+",  
    max_features=5000,        
    min_df=10,                 
    max_df=0.5                
)

X = vectorizer.fit_transform(docs_for_clustering)
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5566945 stored elements and shape (312954, 5000)>

# %%
from sklearn.cluster import KMeans

K = 8

kmeans = KMeans(n_clusters=K, random_state=42, n_init=10)
labels = kmeans.fit_predict(X)

df["cluster"] = labels

cluster_counts = df["cluster"].value_counts().sort_index()
print(cluster_counts)

import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
cluster_counts.plot(kind="bar")
plt.xlabel("Cluster label")
plt.ylabel("Number of articles in sample")
plt.title("Cluster sizes (K-Means, K=8)")
plt.tight_layout()
plt.show()
# Out:
# cluster
# 0    162766
# 1      7870
# 2     13730
# 3     38244
# 4      4795
# 5     35291
# 6     32268
# 7     17990
# Name: count, dtype: int64

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

Ks = range(2, 11) 
inertias = []

for k in Ks:
    print(f"Fitting KMeans with K={k}...")
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(X)              
    inertias.append(km.inertia_)

plt.figure(figsize=(6, 4))
plt.plot(list(Ks), inertias, marker="o")
plt.xlabel("Number of clusters (K)")
plt.ylabel("Inertia (within-cluster sum of squares)")
plt.title("Elbow plot for K-Means")
plt.xticks(list(Ks))
plt.tight_layout()
plt.show()
# Out:
# Fitting KMeans with K=2...
# Fitting KMeans with K=3...
# Fitting KMeans with K=4...
# Fitting KMeans with K=5...
# Fitting KMeans with K=6...
# Fitting KMeans with K=7...
# Fitting KMeans with K=8...
# Fitting KMeans with K=9...
# Fitting KMeans with K=10...

# %%
import numpy as np

terms = np.array(vectorizer.get_feature_names_out())
order_centroids = kmeans.cluster_centers_.argsort(axis=1)[:, ::-1]

for c in range(K):
    top_terms = terms[order_centroids[c, :30]]
    print(f"Cluster {c}")
    print("Top terms:", ", ".join(top_terms))
    print()

for c in range(K):
    print(f"Cluster {c}  top sources")
    print(df.loc[df["cluster"] == c, "source"].value_counts().head(5))
    print()
# Out:
# Cluster 0
# Top terms: いう, ない, なっ, 無, 人, よる, あり, 前, 一, 話し, でき, 同, あっ, 東京, 見, いい, 自分, メートル, なく, 中, なり, 時間, 世界, 発表, 会社, 町, 会, 部, 今, 米
#
# Cluster 1
# Top terms: 時, 午後, 午前, 分, ごろ, 半, 時間, 市, 同, よる, 無料, 問い合わせ, 町, 円, 電話, 区, 県, 会, 入場, 前, 男性, いう, 東京, メートル, 同日, 日本, あっ, 行わ, 紙面, キロ
#
# Cluster 2
# Top terms: 円, 万, 億, ドル, 銭, 市場, 兆, 価格, ユーロ, 年度, ．, 台, 比, 額, 販売, 同, よる, 平均, 増, 東京, 取引, 総額, なっ, 事業, 前日, 市, 減, 期, いう, 発表
#
# Cluster 3
# Top terms: 原発, 首相, 会, つい, 政府, 民主, 委員, 事故, 電力, 問題, 政権, 原子, 経済, 案, 自民, 福島, 述べ, 知事, 安全, 大統領, 示し, 選挙, ない, 議員, 会議, 政治, 方針, 県, 協議, 国民
#
# Cluster 4
# Top terms: 容疑, 逮捕, 疑い, 捜査, 市, 県, よる, 違反, 区, 同署, 事件, 女性, 認め, ごろ, 警視, 課, いう, 法, 供述, 無職, 会社, 男性, 円, 現金, 調べ, 万, 殺害, 男, 時, 自宅
#
# Cluster 5
# Top terms: 回, 選手, 大会, 試合, 決勝, 出場, 優勝, 監督, チーム, 点, リーグ, 日本, 野球, 秒, 勝, 世界, 分, 女子, 初, 五輪, 男子, 高校, 代表, 安打, 今季, 予選, 投手, 連続, なっ, 共同
#
# Cluster 6
# Top terms: 市, 県, 町, 会, 苫小牧, 区, 福島, よる, 大阪, 学校, 開か, 村, 千歳, 市民, 同市, 参加, 避難, いう, なっ, 市長, センター, 地, 同, 宮城, 部, 地域, 福岡, 府, 京都, 万
#
# Cluster 7
# Top terms: 日本, 震災, 東, 被災, 地, 復興, 県, 西, 支援, 新聞, いう, 市, なっ, 東京, 世界, 代表, 影響, 受け, よる, 中国, 福島, 発表, 被害, 協会, 時間, 会, 宮城, 東北, 韓国, 一
#
# Cluster 0  top sources
# source
# mainichi.jp          23468
# nikkei.com           21249
# sankei.jp.msn.com    18897
# yomiuri.co.jp        15600
# tomamin.co.jp        14963
# Name: count, dtype: int64
#
# Cluster 1  top sources
# source
# tomamin.co.jp        1183
# mainichi.jp          1096
# sankei.jp.msn.com     717
# oita-press.co.jp      633
# sanspo.com            629
# Name: count, dtype: int64
#
# Cluster 2  top sources
# source
# sankei.jp.msn.com    1595
# nikkei.com           1591
# asahi.com            1583
# mainichi.jp          1572
# oita-press.co.jp     1445
# Name: count, dtype: int64
#
# Cluster 3  top sources
# source
# mainichi.jp          8246
# sankei.jp.msn.com    7399
# asahi.com            6217
# oita-press.co.jp     4266
# nishinippon.co.jp    2448
# Name: count, dtype: int64
#
# Cluster 4  top sources
# source
# sanspo.com           1157
# sankei.jp.msn.com     905
# oita-press.co.jp      886
# mainichi.jp           628
# nishinippon.co.jp     278
# Name: count, dtype: int64
#
# Cluster 5  top sources
# source
# nikkansports.com     12209
# sanspo.com            6975
# nishinippon.co.jp     2774
# mainichi.jp           2363
# oita-press.co.jp      2183
# Name: count, dtype: int64
#
# Cluster 6  top sources
# source
# mainichi.jp          5222
# tomamin.co.jp        5189
# nishinippon.co.jp    3388
# oita-press.co.jp     2867
# sankei.jp.msn.com    2778
# Name: count, dtype: int64
#
# Cluster 7  top sources
# source
# sankei.jp.msn.com    2368
# sanspo.com           2316
# mainichi.jp          2061
# oita-press.co.jp     1988
# nikkei.com           1751
# Name: count, dtype: int64

# %% [markdown]
# ## Q2: Association rule mining (linguistic associations)

# %%
from collections import Counter

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules

sample = df
N_SAMPLE = 40_000  
MIN_DOC_FREQ = 300  
MIN_SUPPORT = 0.008 
MIN_LIFT = 1.25
MAX_ANTECEDENT_SIZE = 2  

doc_freq = Counter()
for tokens in sample["tokens"]:
    for t in set(tokens):
        doc_freq[t] += 1

vocab = {t for t, c in doc_freq.items() if c >= MIN_DOC_FREQ}
print(f"Articles: {len(sample):,} | vocab after min_df≥{MIN_DOC_FREQ}: {len(vocab):,}")

def to_transaction(tokens):
    return sorted({t for t in tokens if t in vocab})

transactions = [to_transaction(toks) for toks in sample["tokens"]]
transactions = [t for t in transactions if len(t) >= 2]
print(f"Transactions with ≥2 items: {len(transactions):,}")

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_ohe = pd.DataFrame(te_ary, columns=te.columns_)

freq_itemsets = fpgrowth(df_ohe, min_support=MIN_SUPPORT, use_colnames=True)
print(f"Frequent itemsets (min_support={MIN_SUPPORT}, FP-Growth): {len(freq_itemsets):,}")

rules = association_rules(freq_itemsets, metric="lift", min_threshold=MIN_LIFT)
def ant_len(fs):
    return len(fs)

rules = rules[rules["antecedents"].map(ant_len) <= MAX_ANTECEDENT_SIZE]
rules = rules[rules["consequents"].map(ant_len) == 1]
rules = rules.sort_values(["lift", "confidence"], ascending=False)

display_cols = [
    "antecedents",
    "consequents",
    "antecedent support",
    "consequent support",
    "support",
    "confidence",
    "lift",
    "leverage",
]
print(f"Rules after lift≥{MIN_LIFT} and size filters: {len(rules):,}")
rules[display_cols].head(40)
# Out:
# Articles: 312,954 | vocab after min_df≥300: 4,142
# Transactions with ≥2 items: 304,069
# Frequent itemsets (min_support=0.008, FP-Growth): 568
# Rules after lift≥1.25 and size filters: 136
#              antecedents      consequents  antecedent support  \
# 167      frozenset({逮捕})  frozenset({容疑})            0.012106
# 166      frozenset({容疑})  frozenset({逮捕})            0.017851
# 67       frozenset({携帯})  frozenset({電話})            0.010899
# 66       frozenset({電話})  frozenset({携帯})            0.017950
# 109      frozenset({記者})  frozenset({会見})            0.015987
# 108      frozenset({会見})  frozenset({記者})            0.017986
# 16   frozenset({福島, 事故})  frozenset({原発})            0.010343
# 17   frozenset({福島, 原発})  frozenset({事故})            0.012898
# 18   frozenset({事故, 原発})  frozenset({福島})            0.013757
# 60   frozenset({日本, 震災})   frozenset({東})            0.028043
# 146   frozenset({被災, 東})  frozenset({震災})            0.008995
# 141  frozenset({被災, 日本})   frozenset({東})            0.010429
# 59    frozenset({東, 日本})  frozenset({震災})            0.029865
# 135  frozenset({被災, 日本})  frozenset({震災})            0.010429
# 12       frozenset({事故})  frozenset({原発})            0.024360
# 13       frozenset({原発})  frozenset({事故})            0.026869
# 147  frozenset({被災, 震災})   frozenset({東})            0.011606
# 96       frozenset({福島})  frozenset({原発})            0.025997
# 97       frozenset({原発})  frozenset({福島})            0.026869
# 126      frozenset({被災})   frozenset({地})            0.024606
# 127       frozenset({地})  frozenset({被災})            0.028434
# 110      frozenset({電力})  frozenset({原発})            0.018594
# 111      frozenset({原発})  frozenset({電力})            0.026869
# 15       frozenset({事故})  frozenset({福島})            0.024360
# 14       frozenset({福島})  frozenset({事故})            0.025997
# 54        frozenset({東})  frozenset({震災})            0.039307
# 55       frozenset({震災})   frozenset({東})            0.041274
# 103      frozenset({午後})   frozenset({時})            0.024942
# 102       frozenset({時})  frozenset({午後})            0.058546
# 23        frozenset({円})   frozenset({億})            0.061821
# 22        frozenset({億})   frozenset({円})            0.023268
# 148   frozenset({東, 震災})  frozenset({被災})            0.026412
# 136  frozenset({日本, 震災})  frozenset({被災})            0.028043
# 101      frozenset({午前})   frozenset({時})            0.023426
# 100       frozenset({時})  frozenset({午前})            0.058546
# 81        frozenset({都})  frozenset({東京})            0.016158
# 80       frozenset({東京})   frozenset({都})            0.051633
# 142   frozenset({東, 日本})  frozenset({被災})            0.029865
# 104       frozenset({時})  frozenset({ごろ})            0.058546
# 105      frozenset({ごろ})   frozenset({時})            0.012145
#
#      consequent support   support  confidence       lift  leverage
# 167            0.017851  0.009455    0.781038  43.752648  0.009239
# 166            0.012106  0.009455    0.529661  43.752648  0.009239
# 67             0.017950  0.008324    0.763730  42.547912  0.008128
# 66             0.010899  0.008324    0.463723  42.547912  0.008128
# 109            0.017986  0.010267    0.642255  35.708491  0.009980
# 108            0.015987  0.010267    0.570854  35.708491  0.009980
# 16             0.026869  0.009488    0.917329  34.140923  0.009210
# 17             0.024360  0.009488    0.735594  30.197294  0.009174
# 18             0.025997  0.009488    0.689696  26.529449  0.009130
# 60             0.039307  0.026267    0.936672  23.829722  0.025165
# 146            0.041274  0.008801    0.978428  23.705941  0.008429
# 141            0.039307  0.008889    0.852412  21.686095  0.008480
# 59             0.041274  0.026267    0.879529  21.309754  0.025034
# 135            0.041274  0.009100    0.872595  21.141770  0.008669
# 12             0.026869  0.013757    0.564736  21.018204  0.013102
# 13             0.024360  0.013757    0.511995  21.018204  0.013102
# 147            0.039307  0.008801    0.758288  19.291501  0.008344
# 96             0.026869  0.012898    0.496142  18.465276  0.012200
# 97             0.025997  0.012898    0.480049  18.465276  0.012200
# 126            0.028434  0.012280    0.499064  17.551471  0.011580
# 127            0.024606  0.012280    0.431876  17.551471  0.011580
# 110            0.026869  0.008659    0.465688  17.331859  0.008160
# 111            0.018594  0.008659    0.322277  17.331859  0.008160
# 15             0.025997  0.010343    0.424598  16.332346  0.009710
# 14             0.024360  0.010343    0.397849  16.332346  0.009710
# 54             0.041274  0.026412    0.671938  16.280115  0.024789
# 55             0.039307  0.026412    0.639920  16.280115  0.024789
# 103            0.058546  0.020347    0.815796  13.934299  0.018887
# 102            0.024942  0.020347    0.347545  13.934299  0.018887
# 23             0.023268  0.019630    0.317534  13.646951  0.018192
# 22             0.061821  0.019630    0.843675  13.646951  0.018192
# 148            0.024606  0.008801    0.333209  13.541629  0.008151
# 136            0.024606  0.009100    0.324499  13.187648  0.008410
# 101            0.058546  0.017312    0.739014  12.622817  0.015940
# 100            0.023426  0.017312    0.295697  12.622817  0.015940
# 81             0.051633  0.010317    0.638510  12.366313  0.009482
# 80             0.016158  0.010317    0.199809  12.366313  0.009482
# 142            0.024606  0.008889    0.297654  12.096697  0.008155
# 104            0.012145  0.008459    0.144478  11.895837  0.007748
# 105            0.058546  0.008459    0.696453  11.895837  0.007748

# %%
TOP_N = 18
if len(rules) == 0:
    print("No rules passed filters — lower MIN_LIFT or MIN_SUPPORT, or reduce MIN_DOC_FREQ.")
else:
    top = rules.head(TOP_N).copy()

    def rule_label(row):
        a = ", ".join(sorted(row["antecedents"]))
        c = ", ".join(sorted(row["consequents"]))
        return f"{a}  ⇒  {c}"

    top["label"] = top.apply(rule_label, axis=1)
    fig, ax = plt.subplots(figsize=(10, max(5, TOP_N * 0.35)))
    y = np.arange(len(top))
    ax.barh(y, top["lift"].values, color="steelblue", alpha=0.85)
    ax.set_yticks(y)
    ax.set_yticklabels(top["label"].values, fontsize=9)
    ax.invert_yaxis()
    ax.set_xlabel("Lift")
    ax.set_title(f"Top {len(top)} association rules by lift (Q2)")
    plt.tight_layout()
    plt.show()

print(top[display_cols].to_string(index=False))
# Out:
#         antecedents     consequents  antecedent support  consequent support  support  confidence      lift  leverage
#     frozenset({逮捕}) frozenset({容疑})            0.012106            0.017851 0.009455    0.781038 43.752648  0.009239
#     frozenset({容疑}) frozenset({逮捕})            0.017851            0.012106 0.009455    0.529661 43.752648  0.009239
#     frozenset({携帯}) frozenset({電話})            0.010899            0.017950 0.008324    0.763730 42.547912  0.008128
#     frozenset({電話}) frozenset({携帯})            0.017950            0.010899 0.008324    0.463723 42.547912  0.008128
#     frozenset({記者}) frozenset({会見})            0.015987            0.017986 0.010267    0.642255 35.708491  0.009980
#     frozenset({会見}) frozenset({記者})            0.017986            0.015987 0.010267    0.570854 35.708491  0.009980
# frozenset({福島, 事故}) frozenset({原発})            0.010343            0.026869 0.009488    0.917329 34.140923  0.009210
# frozenset({福島, 原発}) frozenset({事故})            0.012898            0.024360 0.009488    0.735594 30.197294  0.009174
# frozenset({事故, 原発}) frozenset({福島})            0.013757            0.025997 0.009488    0.689696 26.529449  0.009130
# frozenset({日本, 震災})  frozenset({東})            0.028043            0.039307 0.026267    0.936672 23.829722  0.025165
#  frozenset({被災, 東}) frozenset({震災})            0.008995            0.041274 0.008801    0.978428 23.705941  0.008429
# frozenset({被災, 日本})  frozenset({東})            0.010429            0.039307 0.008889    0.852412 21.686095  0.008480
#  frozenset({東, 日本}) frozenset({震災})            0.029865            0.041274 0.026267    0.879529 21.309754  0.025034
# frozenset({被災, 日本}) frozenset({震災})            0.010429            0.041274 0.009100    0.872595 21.141770  0.008669
#     frozenset({事故}) frozenset({原発})            0.024360            0.026869 0.013757    0.564736 21.018204  0.013102
#     frozenset({原発}) frozenset({事故})            0.026869            0.024360 0.013757    0.511995 21.018204  0.013102
# frozenset({被災, 震災})  frozenset({東})            0.011606            0.039307 0.008801    0.758288 19.291501  0.008344
#     frozenset({福島}) frozenset({原発})            0.025997            0.026869 0.012898    0.496142 18.465276  0.012200
